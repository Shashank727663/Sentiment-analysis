# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn import metrics

# %%
df=pd.read_csv('/content/stock_market_crash_2022.csv')

# %% [markdown]
# Cleaning the dataset

# %%
df
# Out:
#                         id                                               text  \
# 0      1538666561615015938      When will the #NYSE #stockmarketcrash happen?
# 1      1538665013799489536  Aaj ka gyan:\n\nIf a company isn't a quality c...
# 2      1538660868027830274  The stock market needs to crash hard to make i...
# 3      1538657239849836544  Those who are "Buying on DIP" will very soon b...
# 4      1538654339044196358  @rdrhwke I wish our so-called President were t...
# ...                    ...                                                ...
# 33941  1477645974382260225  Hey #btc maxis!!\n\nDo you know what a Fibonac...
# 33942  1477633718726672397  @cryptolifemama #XRP and #HBAR will be resista...
# 33943  1477533720894656512  $SPY $SPX\nNotes From a #Market #Degenerate: \...
# 33944  1477472665799733249  @chip82many @GarethSoloway Depends if you thin...
# 33945  1477401716291158020  It looks like the market wants to fully enter ...
#
#       text_sentiment         username  \
# 0            Neutral        tradexlnc
# 1           Negative      niftymonday
# 2           Negative       kyle132313
# 3            Neutral  ChintanRajput16
# 4           Positive      DrPCJustice
# ...              ...              ...
# 33941        Neutral   captcrypto2020
# 33942        Neutral  sharecryptoinfo
# 33943       Positive       LyfeOfPELK
# 33944       Positive       i_danforth
# 33945       Positive        ludo_slav
#
#                                                 hashtags  \
# 0                           ['NYSE', 'stockmarketcrash']
# 1      ['stockmarkets', 'stockmarketcrash', 'trading'...
# 2         ['stockmarketcrash', 'economy', 'rich', 'Fed']
# 3      ['stockmarketcrash', 'StocksToBuy', 'stockstow...
# 4      ['Bidenomics', 'inflation', 'recession', 'stoc...
# ...                                                  ...
# 33941                              ['btc', 'bearmarket']
# 33942                      ['XRP', 'HBAR', 'bearmarket']
# 33943  ['Market', 'Degenerate', 'Chinese', 'China', '...
# 33944            ['BullMarket', 'BearMarket', 'onchain']
# 33945                ['crypto', 'bearmarket', 'BULLISH']
#
#                       created_at  user followers count  replycount  \
# 0      2022-06-19 23:34:29+00:00                 10669           0
# 1      2022-06-19 23:28:20+00:00                   100           0
# 2      2022-06-19 23:11:52+00:00                     0           0
# 3      2022-06-19 22:57:27+00:00                    54           0
# 4      2022-06-19 22:45:55+00:00                    28           0
# ...                          ...                   ...         ...
# 33941  2022-01-02 14:20:28+00:00                    54           2
# 33942  2022-01-02 13:31:46+00:00                    24           1
# 33943  2022-01-02 06:54:24+00:00                   576           2
# 33944  2022-01-02 02:51:48+00:00                   326           1
# 33945  2022-01-01 22:09:52+00:00                    32           2
#
#        retweetcount  likecount  quotecount language  media  retweetedTweet  \
# 0                 0          1           0       en    NaN             NaN
# 1                 1          8           0       en    NaN             NaN
# 2                 0          0           0       en    NaN             NaN
# 3                 2          2           0       en    NaN             NaN
# 4                 0          0           0       en    NaN             NaN
# ...             ...        ...         ...      ...    ...             ...
# 33941             0          0           0       en    NaN             NaN
# 33942             0          2           0       en    NaN             NaN
# 33943             1          2           0       en    NaN             NaN
# 33944             0          0           0       en    NaN             NaN
# 33945             0          2           0       en    NaN             NaN
#
#        quotedtweet  inReplyToTweetId                       inReplyToUser  \
# 0              NaN               NaN                                 NaN
# 1              NaN               NaN                                 NaN
# 2              NaN               NaN                                 NaN
# 3              NaN               NaN                                 NaN
# 4              NaN      1.538653e+18         https://twitter.com/rdrhwke
# ...            ...               ...                                 ...
# 33941          NaN               NaN                                 NaN
# 33942          NaN      1.477320e+18  https://twitter.com/cryptolifemama
# 33943          NaN               NaN                                 NaN
# 33944          NaN      1.477398e+18      https://twitter.com/chip82many
# 33945          NaN               NaN                                 NaN
#
#                                           mentionedUsers
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4      [User(username='rdrhwke', id=43753976, display...
# ...                                                  ...
# 33941                                                NaN
# 33942  [User(username='cryptolifemama', id=1386086414...
# 33943                                                NaN
# 33944  [User(username='chip82many', id=2369790510, di...
# 33945                                                NaN
#
# [33946 rows x 18 columns]

# %%
df.duplicated().sum()
# Out:
# 300

# %%
 df.drop_duplicates()
# Out:
#                         id                                               text  \
# 20857  1538670262874361857  Being in a #Crypto #Bearmarket is a difficult ...
# 20858  1538669818865655808  Whats next for 🐶 1 Tesla accept doge or 2 any ...
# 20859  1538668600826990592  Tbh this #bearmarket will last as long as peop...
# 20860  1538666896697982980  Hold still and you will win #NFT  #cryptocurre...
# 0      1538666561615015938      When will the #NYSE #stockmarketcrash happen?
# ...                    ...                                                ...
# 33941  1477645974382260225  Hey #btc maxis!!\n\nDo you know what a Fibonac...
# 33942  1477633718726672397  @cryptolifemama #XRP and #HBAR will be resista...
# 33943  1477533720894656512  $SPY $SPX\nNotes From a #Market #Degenerate: \...
# 33944  1477472665799733249  @chip82many @GarethSoloway Depends if you thin...
# 33945  1477401716291158020  It looks like the market wants to fully enter ...
#
#       text_sentiment         username  \
# 20857       Positive     JonboyCrypto
# 20858       Positive  amritghuman1313
# 20859       Positive    CryptoTakeova
# 20860       Positive           lulymf
# 0            Neutral        tradexlnc
# ...              ...              ...
# 33941        Neutral   captcrypto2020
# 33942        Neutral  sharecryptoinfo
# 33943       Positive       LyfeOfPELK
# 33944       Positive       i_danforth
# 33945       Positive        ludo_slav
#
#                                                 hashtags  \
# 20857  ['Crypto', 'Bearmarket', 'HEX', 'Pulsechain', ...
# 20858  ['dogecoin', 'cryptocurrency', 'doge', 'memeco...
# 20859              ['bearmarket', 'WeControlTheMarkets']
# 20860            ['NFT', 'cryptocurrency', 'bearmarket']
# 0                           ['NYSE', 'stockmarketcrash']
# ...                                                  ...
# 33941                              ['btc', 'bearmarket']
# 33942                      ['XRP', 'HBAR', 'bearmarket']
# 33943  ['Market', 'Degenerate', 'Chinese', 'China', '...
# 33944            ['BullMarket', 'BearMarket', 'onchain']
# 33945                ['crypto', 'bearmarket', 'BULLISH']
#
#                       created_at  user followers count  replycount  \
# 20857  2022-06-19 23:49:12+00:00                   579           2
# 20858  2022-06-19 23:47:26+00:00                    12           0
# 20859  2022-06-19 23:42:36+00:00                    12           0
# 20860  2022-06-19 23:35:49+00:00                   165           0
# 0      2022-06-19 23:34:29+00:00                 10669           0
# ...                          ...                   ...         ...
# 33941  2022-01-02 14:20:28+00:00                    54           2
# 33942  2022-01-02 13:31:46+00:00                    24           1
# 33943  2022-01-02 06:54:24+00:00                   576           2
# 33944  2022-01-02 02:51:48+00:00                   326           1
# 33945  2022-01-01 22:09:52+00:00                    32           2
#
#        retweetcount  likecount  quotecount language  media  retweetedTweet  \
# 20857             1         23           0       en    NaN             NaN
# 20858             0          0           0       en    NaN             NaN
# 20859             0          0           0       en    NaN             NaN
# 20860             0          1           0       en    NaN             NaN
# 0                 0          1           0       en    NaN             NaN
# ...             ...        ...         ...      ...    ...             ...
# 33941             0          0           0       en    NaN             NaN
# 33942             0          2           0       en    NaN             NaN
# 33943             1          2           0       en    NaN             NaN
# 33944             0          0           0       en    NaN             NaN
# 33945             0          2           0       en    NaN             NaN
#
#        quotedtweet  inReplyToTweetId                       inReplyToUser  \
# 20857          NaN               NaN                                 NaN
# 20858          NaN               NaN                                 NaN
# 20859          NaN               NaN                                 NaN
# 20860          NaN               NaN                                 NaN
# 0              NaN               NaN                                 NaN
# ...            ...               ...                                 ...
# 33941          NaN               NaN                                 NaN
# 33942          NaN      1.477320e+18  https://twitter.com/cryptolifemama
# 33943          NaN               NaN                                 NaN
# 33944          NaN      1.477398e+18      https://twitter.com/chip82many
# 33945          NaN               NaN                                 NaN
#
#                                           mentionedUsers
# 20857  [User(username='RichardHeartWin', id=817817720...
# 20858  [User(username='dogecoin', id=2235729541, disp...
# 20859                                                NaN
# 20860                                                NaN
# 0                                                    NaN
# ...                                                  ...
# 33941                                                NaN
# 33942  [User(username='cryptolifemama', id=1386086414...
# 33943                                                NaN
# 33944  [User(username='chip82many', id=2369790510, di...
# 33945                                                NaN
#
# [33646 rows x 18 columns]

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df
# Out:
#                         id                                               text  \
# 20857  1538670262874361857  Being in a #Crypto #Bearmarket is a difficult ...
# 20858  1538669818865655808  Whats next for 🐶 1 Tesla accept doge or 2 any ...
# 20859  1538668600826990592  Tbh this #bearmarket will last as long as peop...
# 20860  1538666896697982980  Hold still and you will win #NFT  #cryptocurre...
# 0      1538666561615015938      When will the #NYSE #stockmarketcrash happen?
# ...                    ...                                                ...
# 33941  1477645974382260225  Hey #btc maxis!!\n\nDo you know what a Fibonac...
# 33942  1477633718726672397  @cryptolifemama #XRP and #HBAR will be resista...
# 33943  1477533720894656512  $SPY $SPX\nNotes From a #Market #Degenerate: \...
# 33944  1477472665799733249  @chip82many @GarethSoloway Depends if you thin...
# 33945  1477401716291158020  It looks like the market wants to fully enter ...
#
#       text_sentiment         username  \
# 20857       Positive     JonboyCrypto
# 20858       Positive  amritghuman1313
# 20859       Positive    CryptoTakeova
# 20860       Positive           lulymf
# 0            Neutral        tradexlnc
# ...              ...              ...
# 33941        Neutral   captcrypto2020
# 33942        Neutral  sharecryptoinfo
# 33943       Positive       LyfeOfPELK
# 33944       Positive       i_danforth
# 33945       Positive        ludo_slav
#
#                                                 hashtags  \
# 20857  ['Crypto', 'Bearmarket', 'HEX', 'Pulsechain', ...
# 20858  ['dogecoin', 'cryptocurrency', 'doge', 'memeco...
# 20859              ['bearmarket', 'WeControlTheMarkets']
# 20860            ['NFT', 'cryptocurrency', 'bearmarket']
# 0                           ['NYSE', 'stockmarketcrash']
# ...                                                  ...
# 33941                              ['btc', 'bearmarket']
# 33942                      ['XRP', 'HBAR', 'bearmarket']
# 33943  ['Market', 'Degenerate', 'Chinese', 'China', '...
# 33944            ['BullMarket', 'BearMarket', 'onchain']
# 33945                ['crypto', 'bearmarket', 'BULLISH']
#
#                       created_at  user followers count  replycount  \
# 20857  2022-06-19 23:49:12+00:00                   579           2
# 20858  2022-06-19 23:47:26+00:00                    12           0
# 20859  2022-06-19 23:42:36+00:00                    12           0
# 20860  2022-06-19 23:35:49+00:00                   165           0
# 0      2022-06-19 23:34:29+00:00                 10669           0
# ...                          ...                   ...         ...
# 33941  2022-01-02 14:20:28+00:00                    54           2
# 33942  2022-01-02 13:31:46+00:00                    24           1
# 33943  2022-01-02 06:54:24+00:00                   576           2
# 33944  2022-01-02 02:51:48+00:00                   326           1
# 33945  2022-01-01 22:09:52+00:00                    32           2
#
#        retweetcount  likecount  quotecount language  media  retweetedTweet  \
# 20857             1         23           0       en    NaN             NaN
# 20858             0          0           0       en    NaN             NaN
# 20859             0          0           0       en    NaN             NaN
# 20860             0          1           0       en    NaN             NaN
# 0                 0          1           0       en    NaN             NaN
# ...             ...        ...         ...      ...    ...             ...
# 33941             0          0           0       en    NaN             NaN
# 33942             0          2           0       en    NaN             NaN
# 33943             1          2           0       en    NaN             NaN
# 33944             0          0           0       en    NaN             NaN
# 33945             0          2           0       en    NaN             NaN
#
#        quotedtweet  inReplyToTweetId                       inReplyToUser  \
# 20857          NaN               NaN                                 NaN
# 20858          NaN               NaN                                 NaN
# 20859          NaN               NaN                                 NaN
# 20860          NaN               NaN                                 NaN
# 0              NaN               NaN                                 NaN
# ...            ...               ...                                 ...
# 33941          NaN               NaN                                 NaN
# 33942          NaN      1.477320e+18  https://twitter.com/cryptolifemama
# 33943          NaN               NaN                                 NaN
# 33944          NaN      1.477398e+18      https://twitter.com/chip82many
# 33945          NaN               NaN                                 NaN
#
#                                           mentionedUsers
# 20857  [User(username='RichardHeartWin', id=817817720...
# 20858  [User(username='dogecoin', id=2235729541, disp...
# 20859                                                NaN
# 20860                                                NaN
# 0                                                    NaN
# ...                                                  ...
# 33941                                                NaN
# 33942  [User(username='cryptolifemama', id=1386086414...
# 33943                                                NaN
# 33944  [User(username='chip82many', id=2369790510, di...
# 33945                                                NaN
#
# [33646 rows x 18 columns]

# %%
#checking for the null values 
df.isnull().sum()
# Out:
# id                          0
# text                        0
# text_sentiment              0
# username                    0
# hashtags                    1
# created_at                  0
# user followers count        0
# replycount                  0
# retweetcount                0
# likecount                   0
# quotecount                  0
# language                    0
# media                   33646
# retweetedTweet          33646
# quotedtweet             33646
# inReplyToTweetId        28753
# inReplyToUser           28753
# mentionedUsers          28176
# dtype: int64

# %%
df=df.interpolate()

# %%
df.fillna(value='', inplace=True)

# %%
df.isnull().sum()
# Out:
# id                      0
# text                    0
# text_sentiment          0
# username                0
# hashtags                0
# created_at              0
# user followers count    0
# replycount              0
# retweetcount            0
# likecount               0
# quotecount              0
# language                0
# media                   0
# retweetedTweet          0
# quotedtweet             0
# inReplyToTweetId        0
# inReplyToUser           0
# mentionedUsers          0
# dtype: int64

# %%
# convert the text data into numerical representations
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(df['text'])

# %%
y=df['text_sentiment']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
clf = MultinomialNB()
clf.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
# evaluate the performance of the algorithm on the test data
y_pred = clf.predict(X_test)
print('Accuracy: ', metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy:  0.6398216939078751

# %%
print(y_pred)
# Out:
# ['Positive' 'Negative' 'Positive' ... 'Positive' 'Positive' 'Neutral']
